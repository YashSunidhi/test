# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %%
train = pd.read_csv(r'C:\Users\sm17376\Downloads\suyash Personal\Kaggle\train_sample.csv\mnt\ssd\kaggle-talkingdata2\competition_files\train_sample.csv')

# %%
train.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38             NaN
# 1  105560   25       1  17      259  2017-11-07 13:40:27             NaN
# 2  101424   12       1  19      212  2017-11-07 18:05:24             NaN
# 3   94584   13       1  13      477  2017-11-07 04:58:08             NaN
# 4   68413   12       1   1      178  2017-11-09 09:00:09             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
train['date'] = pd.to_datetime(train['click_time']).dt.date
train['time'] = pd.to_datetime(train['click_time']).dt.time
train['year'] = pd.to_datetime(train['date']).dt.year
train['month'] = pd.to_datetime(train['date']).dt.month
train['day'] = pd.to_datetime(train['date']).dt.day

# %%
train['datetime'] = pd.to_datetime(train['click_time'])
train['dow']      = train['datetime'].dt.dayofweek
train["doy"]      = train["datetime"].dt.dayofyear
train["hour"]    = train["datetime"].dt.hour
train["minute"]    = train["datetime"].dt.minute

# %%
train.drop(['click_time'],axis =1)
# Out:
#            ip  app  device  os  channel attributed_time  is_attributed  \
# 0       87540   12       1  13      497             NaN              0
# 1      105560   25       1  17      259             NaN              0
# 2      101424   12       1  19      212             NaN              0
# 3       94584   13       1  13      477             NaN              0
# 4       68413   12       1   1      178             NaN              0
# 5       93663    3       1  17      115             NaN              0
# 6       17059    1       1  17      135             NaN              0
# 7      121505    9       1  25      442             NaN              0
# 8      192967    2       2  22      364             NaN              0
# 9      143636    3       1  19      135             NaN              0
# 10      73839    3       1  22      489             NaN              0
# 11      34812    3       1  13      489             NaN              0
# ...

# %%
train['app'].hist()

# %%
train['channel'].hist()

# %%
train['os'].hist()

# %%
train.groupby('is_attributed')['hour'].hist()
# Out:
# is_attributed
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: hour, dtype: object

# %%
train['dow'].hist()

# %%
train['dow'].describe()
# Out:
# count    100000.000000
# mean          1.861460
# std           0.889266
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max           3.000000
# Name: dow, dtype: float64

# %%
train.describe()
# Out:
#                   ip           app         device             os  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean    91255.879670      12.04788      21.771250      22.818280
# std     69835.553661      14.94150     259.667767      55.943136
# min         9.000000       1.00000       0.000000       0.000000
# 25%     40552.000000       3.00000       1.000000      13.000000
# 50%     79827.000000      12.00000       1.000000      18.000000
# 75%    118252.000000      15.00000       1.000000      19.000000
# max    364757.000000     551.00000    3867.000000     866.000000
#
#              channel  is_attributed      year     month            day  \
# count  100000.000000  100000.000000  100000.0  100000.0  100000.000000
# mean      268.832460       0.002270    2017.0      11.0       7.861460
# std       129.724248       0.047591       0.0       0.0       0.889266
# min         3.000000       0.000000    2017.0      11.0       6.000000
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
# ip                 100000 non-null int64
# app                100000 non-null int64
# device             100000 non-null int64
# os                 100000 non-null int64
# channel            100000 non-null int64
# click_time         100000 non-null object
# attributed_time    227 non-null object
# is_attributed      100000 non-null int64
# date               100000 non-null object
# time               100000 non-null object
# year               100000 non-null int64
# month              100000 non-null int64
# day                100000 non-null int64
# hours              100000 non-null int64
# datetime           100000 non-null datetime64[ns]
# dow                100000 non-null int64
# doy                100000 non-null int64
# hour               100000 non-null int64
# minute             100000 non-null int64
# dtypes: datetime64[ns](1), int64(14), object(4)
# ...

# %%
train['dow'].hist()

# %%
train['hour'].hist()

# %%
train[train['is_attributed']==1].hour.hist()

# %%
train[train['is_attributed']==0].hour.hist()

# %%
a = train[train['is_attributed']==1]

# %%
a.shape
# Out:
# (227, 19)

# %%
a.head()
# Out:
#           ip  app  device  os  channel           click_time  \
# 284   224120   19       0  29      213  2017-11-08 02:22:13
# 481   272894   10       1   7      113  2017-11-08 06:10:05
# 1208   79001   19       0   0      213  2017-11-07 09:54:22
# 1341  131029   19       0   0      343  2017-11-09 10:58:46
# 1412   40352   19       0   0      213  2017-11-07 22:19:03
#
#           attributed_time  is_attributed        date      time  year  month  \
# 284   2017-11-08 02:22:38              1  2017-11-08  02:22:13  2017     11
# 481   2017-11-08 06:10:37              1  2017-11-08  06:10:05  2017     11
# 1208  2017-11-07 11:59:05              1  2017-11-07  09:54:22  2017     11
# 1341  2017-11-09 11:52:01              1  2017-11-09  10:58:46  2017     11
# 1412  2017-11-08 01:55:02              1  2017-11-07  22:19:03  2017     11
#
#       day  hours            datetime  dow  doy  hour  minute
# 284     8      9 2017-11-08 02:22:13    2  312     2      22
# ...

# %%
import requests

# The direct link to the Kaggle data set
data_url = 'https://www.kaggle.com/c/8540/download/train_sample.csv.zip'

# The local path where the data set is saved.
local_filename = "sample.csv"

# Kaggle Username and Password
kaggle_info = {'UserName': "smnitrkl50@gmail.com", 'Password': "yash@1234"}

# Attempts to download the CSV file. Gets rejected because we are not logged in.
r = requests.get(data_url)

# Login to Kaggle and retrieve the data.
r = requests.post(r.url, data = kaggle_info, prefetch = False)

# Writes the data to a local file one chunk at a time.
f = open(local_filename, 'w')
for chunk in r.iter_content(chunk_size = 512 * 1024): # Reads 512KB at a time into memory
    if chunk: # filter out keep-alive new chunks
        f.write(chunk)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-8f44b5da2935> in <module>()
#      14
#      15 # Login to Kaggle and retrieve the data.
# ---> 16 r = requests.post(r.url, data = kaggle_info, prefetch = False)
#      17
#      18 # Writes the data to a local file one chunk at a time.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ...
